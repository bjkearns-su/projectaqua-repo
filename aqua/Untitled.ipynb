# %%
import fitbit

authd_client = fitbit.Fitbit('<22CXD3>', '<be89b482d0b92909a4460893dfac7efc>',
                   access_token='eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI2S1NXOFAiLCJhdWQiOiIyMkNYRDMiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyc29jIHJhY3QgcnNldCBybG9jIHJ3ZWkgcmhyIHJwcm8gcm51dCByc2xlIiwiZXhwIjoxNTI0MjIxNjQ5LCJpYXQiOjE1MjQxOTI4NDl9.TFQNXQqXz78pq7bFYW6fqvVOE3NpBBh73YODO6EA6uY>', refresh_token='2c1d5e0ce6ab4afd9a730931cca863d4273a32081f8c8582aec8f089f4679d1f')

authd_client.body()
# Out:
# ---------------------------------------------------------------------------
# HTTPUnauthorized                          Traceback (most recent call last)
# <ipython-input-3-0d15781d130c> in <module>()
#       5                    access_token='eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI2S1NXOFAiLCJhdWQiOiIyMkNYRDMiLCJpc3MiOiJGaXRiaXQiLCJ0eXAiOiJhY2Nlc3NfdG9rZW4iLCJzY29wZXMiOiJyc29jIHJhY3QgcnNldCBybG9jIHJ3ZWkgcmhyIHJwcm8gcm51dCByc2xlIiwiZXhwIjoxNTI0MjIxNjQ5LCJpYXQiOjE1MjQxOTI4NDl9.TFQNXQqXz78pq7bFYW6fqvVOE3NpBBh73YODO6EA6uY>', refresh_token='2c1d5e0ce6ab4afd9a730931cca863d4273a32081f8c8582aec8f089f4679d1f')
#       6
# ----> 7 authd_client.body()
#
# c:\programdata\miniconda3\lib\site-packages\fitbit\utils.py in _curried(*moreargs, **morekwargs)
#      36 def curry(_curried_func, *args, **kwargs):
#      37     def _curried(*moreargs, **morekwargs):
# ---> 38         return _curried_func(*(args+moreargs), **dict(kwargs, **morekwargs))
#      39     return _curried
#
# ...

# %%
help(fitbit.api)
# Out:
# Help on module fitbit.api in fitbit:
#
# NAME
#     fitbit.api - # -*- coding: utf-8 -*-
#
# CLASSES
#     builtins.object
#         Fitbit
#         FitbitOauth2Client
#
#     class Fitbit(builtins.object)
#      |  Methods defined here:
#      |
#      |  __init__(self, client_id, client_secret, system='en_US', **kwargs)
#      |      Fitbit(<id>, <secret>, access_token=<token>, refresh_token=<token>)
#      |
#      |  accept_invite(self, other_user_id)
#      |      Convenience method for respond_to_invite
#      |
#      |  activities_daily_goal(self, calories_out=None, active_minutes=None, floors=None, distance=None, steps=None)
#      |      Implements the following APIs for period equal to daily
#      |
#      |      https://dev.fitbit.com/docs/activity/#get-activity-goals
#      |      https://dev.fitbit.com/docs/activity/#update-activity-goals
#      |
#      |      Pass no arguments to get the daily activities goal. Pass any one of
# ...

# %%
authd_client.water_goal()
# Out:
# {'goal': {'goal': 64.00994873046875, 'startDate': '2018-04-15'}}

# %%
authd_client.water_goal()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1a9bae49334a> in <module>()
# ----> 1 authd_client.water_goal()
#
# NameError: name 'authd_client' is not defined
